# %%
import pandas
import numpy as np
import Recommender

# %%
triplets_file = 'https://static.turi.com/datasets/millionsong/10000.txt'
songs_metadata_file = 'song_data.csv'

song_df_1 = pandas.read_table(triplets_file,header=None)
song_df_1.columns = ['user_id', 'song_id', 'listen_count']

song_df_2 =  pandas.read_csv(songs_metadata_file)
song_df = pandas.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on="song_id", how="left")
# Out:
# /home/eric/.local/lib/python2.7/site-packages/ipykernel_launcher.py:4: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   after removing the cwd from sys.path.

# %%
song_df = song_df.head(10000)

# %%
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
song_df['song'] = song_df['title'].map(str) + " - " + song_df['artist_name']

# %%
song_df['song'].head()
# Out:
# 0            The Cove - Jack Johnson
# 1    Entre Dos Aguas - Paco De Lucia
# 2              Stronger - Kanye West
# 3      Constellations - Jack Johnson
# 4        Learn To Fly - Foo Fighters
# Name: song, dtype: object

# %%
song_df_grouped = song_df.groupby(['song']).agg({'listen_count': 'count'}).reset_index()
song_df_grouped.sort_values('listen_count',ascending = 0)
# Out:
#                                                    song  listen_count
# 3660                           Sehr kosmisch - Harmonia            45
# 5105                     You're The One - Dwight Yoakam            32
# 4678                                       Undo - Björk            32
# 1071  Dog Days Are Over (Radio Edit) - Florence + Th...            28
# 3655                              Secrets - OneRepublic            28
# 4378                           The Scientist - Coldplay            27
# 4712                       Use Somebody - Kings Of Leon            27
# 3476                            Revelry - Kings Of Leon            26
# 1387                     Fireflies - Charttraxx Karaoke            24
# 1862  Horn Concerto No. 4 in E flat K495: II. Romanc...            23
# 1805                           Hey_ Soul Sister - Train            22
# 5032                                  Yellow - Coldplay            22
# 808                                   Clocks - Coldplay            21
# 2620  Lucky (Album Version) - Jason Mraz & Colbie Ca...            20
# 2299             Just Dance - Lady GaGa / Colby O'Donis            19
# 3064                    OMG - Usher featuring will.i.am            18
# 456   Billionaire [feat. Bruno Mars]  (Explicit Albu...            18
# 2689                                   Marry Me - Train            18
# 4543                                 Tive Sim - Cartola            18
# 1410                            Float On - Modest Mouse            17
# 142                               Alejandro - Lady GaGa            17
# 726   Catch You Baby (Steve Pitron & Max Sanna Radio...            17
# 3868                   Somebody To Love - Justin Bieber            17
# 4465                They Might Follow You - Tiny Vipers            16
# 1143                Drop The World - Lil Wayne / Eminem            16
# 631                               Bulletproof - La Roux            16
# 3038  Nothin' On You [feat. Bruno Mars] (Album Versi...            16
# 899                        Creep (Explicit) - Radiohead            15
# 870                Cosmic Love - Florence + The Machine            15
# 1680                                     Halo - Beyoncé            15
# ...                                                 ...           ...
# 2197                            Irreplaceable - Beyoncé             1
# 2191  Introducing Tobacco To Civilization (LP Versio...             1
# 2138        Imagine Dead John Lennon - Times New Viking             1
# 2190           Intoxication (Album Version) - Disturbed             1
# 2139                              Imanol - Platero Y Tu             1
# 2142                            Immortality - Pearl Jam             1
# 2143                      In A Darkened Room - Skid Row             1
# 2144    In Another Life (Album Version) - The Veronicas             1
# 2145                                    In Church - M83             1
# 2146                               In Limbo - Radiohead             1
# 2150                      In Our Blood - Horse Feathers             1
# 2151                      In Our Nature - José González             1
# 2155                      In The Backseat - Arcade Fire             1
# 2156                     In The Cold I'm Standing - M83             1
# 2163                             In The Sun - She & Him             1
# 2167                  Inaudible Melodies - Jack Johnson             1
# 2172                         Infanta - The Decemberists             1
# 2174                             Infatueighties - Musiq             1
# 2176  Inner City Pressure (Album Version) - Flight O...             1
# 2177                         Innocent Son - Fleet Foxes             1
# 2179                                 Inolvidable - Reik             1
# 2180        Inside The Fire (Album Version) - Disturbed             1
# 2182                       Intergalactic - Beastie Boys             1
# 2184  Interstate Love Song (LP Version) - Stone Temp...             1
# 2185                         Intervention - Arcade Fire             1
# 2186                             Into Dust - Mazzy Star             1
# 2187  Into The Great Wide Open - Tom Petty And The H...             1
# 2188                      Into The Ocean - Blue October             1
# 2189                            Into The White - Pixies             1
# 5150                              Época - Gotan Project             1
#
# [5151 rows x 2 columns]

# %%
users = song_df['user_id'].unique()
len(users)
# Out:
# 365

# %%
items = song_df['song'].unique()
len(items)
# Out:
# 5151

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(song_df, test_size = 0.20, random_state=0)
print(train_data.head(5))
# Out:
#                                        user_id             song_id  \
# 7389  94d5bdc37683950e90c56c9b32721edb5d347600  SOXNZOW12AB017F756
# 9275  1012ecfd277b96487ed8357d02fa8326b13696a5  SOXHYVQ12AB0187949
# 2995  15415fa2745b344bce958967c346f2a89f792f63  SOOSZAZ12A6D4FADF8
# 5316  ffadf9297a99945c0513cd87939d91d8b602936b  SOWDJEJ12A8C1339FE
# 356   5a905f000fc1ff3df7ca807d57edb608863db05d  SOAMPRJ12A8AE45F38
#
#       listen_count                 title  \
# 7389             2      Half Of My Heart
# 9275             1  The Beautiful People
# 2995             1     Sanctify Yourself
# 5316             4     Heart Cooks Brain
# 356             20                 Rorol
#
#                                                 release      artist_name  \
# 7389                                     Battle Studies       John Mayer
# 9275             Antichrist Superstar (Ecopac Explicit)   Marilyn Manson
# 2995                             Glittering Prize 81/92     Simple Minds
# 5316  Everything Is Nice: The Matador Records 10th A...     Modest Mouse
# 356                               Identification Parade  Octopus Project
#
#       year                                   song
# 7389     0          Half Of My Heart - John Mayer
# 9275     0  The Beautiful People - Marilyn Manson
# 2995  1985       Sanctify Yourself - Simple Minds
# 5316  1997       Heart Cooks Brain - Modest Mouse
# 356   2002                Rorol - Octopus Project

# %%
pr = Recommender.Popularity_Recommender()
pr.create(train_data, 'user_id', 'song')

# %%
pr.recommend(users[5])
# Out:
#                                        user_id  \
# 3194  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 4083  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 931   4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 4443  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 3034  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 3189  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 4112  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 1207  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 1577  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 1626  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 3824  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 4385  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 2339  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 2670  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 1998  4bd88bfb25263a75bbdd467e74018f4ae570e5df
#
#                                                    song  score  Rank
# 3194                           Sehr kosmisch - Harmonia     37   1.0
# 4083                                       Undo - Björk     27   2.0
# 931   Dog Days Are Over (Radio Edit) - Florence + Th...     24   3.0
# 4443                     You're The One - Dwight Yoakam     24   4.0
# 3034                            Revelry - Kings Of Leon     21   5.0
# 3189                              Secrets - OneRepublic     21   6.0
# 4112                       Use Somebody - Kings Of Leon     21   7.0
# 1207                     Fireflies - Charttraxx Karaoke     20   8.0
# 1577                           Hey_ Soul Sister - Train     19   9.0
# 1626  Horn Concerto No. 4 in E flat K495: II. Romanc...     19  10.0
# 3824                           The Scientist - Coldplay     19  11.0
# 4385                                  Yellow - Coldplay     19  12.0
# 2339                                   Marry Me - Train     17  13.0
# 2670                    OMG - Usher featuring will.i.am     17  14.0
# 1998             Just Dance - Lady GaGa / Colby O'Donis     16  15.0

# %%
pr.recommend(users[110])
# Out:
#                                        user_id  \
# 3194  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 4083  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 931   881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 4443  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 3034  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 3189  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 4112  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 1207  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 1577  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 1626  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 3824  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 4385  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 2339  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 2670  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
# 1998  881f2e87fe2a45ae27d6e235c156c762ac3cb82a
#
#                                                    song  score  Rank
# 3194                           Sehr kosmisch - Harmonia     37   1.0
# 4083                                       Undo - Björk     27   2.0
# 931   Dog Days Are Over (Radio Edit) - Florence + Th...     24   3.0
# 4443                     You're The One - Dwight Yoakam     24   4.0
# 3034                            Revelry - Kings Of Leon     21   5.0
# 3189                              Secrets - OneRepublic     21   6.0
# 4112                       Use Somebody - Kings Of Leon     21   7.0
# 1207                     Fireflies - Charttraxx Karaoke     20   8.0
# 1577                           Hey_ Soul Sister - Train     19   9.0
# 1626  Horn Concerto No. 4 in E flat K495: II. Romanc...     19  10.0
# 3824                           The Scientist - Coldplay     19  11.0
# 4385                                  Yellow - Coldplay     19  12.0
# 2339                                   Marry Me - Train     17  13.0
# 2670                    OMG - Usher featuring will.i.am     17  14.0
# 1998             Just Dance - Lady GaGa / Colby O'Donis     16  15.0
